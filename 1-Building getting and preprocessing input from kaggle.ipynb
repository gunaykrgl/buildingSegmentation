# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
import random
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Drag and drop kaggle.json at this point
# !mv kaggle.json /root/.kaggle/

# !kaggle datasets download -d balraj98/massachusetts-buildings-dataset
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading massachusetts-buildings-dataset.zip to /content
# 100% 1.49G/1.49G [00:48<00:00, 40.4MB/s]
# 100% 1.49G/1.49G [00:48<00:00, 32.9MB/s]

# %%
# !unzip -qq massachusetts-buildings-dataset.zip

# %%
# Define the path of files to retrieve (only retrieve tiff files)

train_path = "/content/tiff/train"
train_labels_path = "/content/tiff/train_labels"

val_path = "/content/tiff/val"
val_labels_path = "/content/tiff/val_labels"

test_path = "/content/tiff/test"
test_labels_path = "/content/tiff/test_labels"

# %% [markdown]
# In the following cell, images were first sliced with (110, 1390) to get images of (1280, 1280) as 1280 was an integer multiple of 256 (Thus, all the image could be captured without a padding). Then, images of (256, 256) were acquired by a sliding window approach (as sliced data was shaped (1280, 1280), there were acquired 25 images of shape (256, 256))
#
# Later, it was noticed that some images from the dataset had random crops. However, in this study, it was undesirable to have random crops in the input image itself. Therefore, parts of image that had pixels of pure white (rgb --> 255, 255, 255) in more than 25% were eliminated from the data.
#
# An image with a big crop is shown below:
#
# ![23429050_15 (1) (1).png](data:image/png;base64,...)

# %%
def get_images(path, labels_path, patch_size= 256, stride= 256):
  n = 1

  images = []
  masks = []
  white_ratios = []
  print(path, " Number of files: ", len(os.listdir(path)))
  for img_file in os.listdir(path):
    img = Image.open(path + "/"+img_file)
    mask = Image.open(labels_path + "/"+img_file[:-1]) # .tif instead of .tiff

    np_img = np.array(img)
    np_mask = np.array(mask)

    # crop to shape of (1280*1280) to be able to get 5 (256, 256) images
    np_img_resized = np_img[110:1390, 110:1390]
    np_mask_resized = np_mask[110:1390, 110:1390]

    height, width, _ = np_img_resized.shape

    for i in range(0, height, stride):
      for j in range(0, width, stride):
        img_ = np_img_resized[i:i+patch_size, j:j+patch_size]
        mask_ = np_mask_resized[i:i+patch_size, j:j+patch_size]

        # check percentage of white pixels
        number_of_white_pixels = np.sum(np.all(img_ == [255, 255, 255], axis=-1))
        number_of_pixels = img_.shape[0] * img_.shape[1]
        white_ratio = number_of_white_pixels/number_of_pixels
        white_ratios.append(white_ratio)

        if white_ratio > 0.25:
          print("skipping: ", img_file,  " White ratio: ", white_ratio, " position: ", i, j)
          n += 1
          continue
        images.append(np_img_resized[i:i+patch_size, j:j+patch_size])
        masks.append(np_mask_resized[i:i+patch_size, j:j+patch_size, 0])
  np_images = np.array(images)
  np_masks = np.array(masks)

  print("images shape: ",np_images.shape)
  print("masks shape: ", np_masks.shape)
  print(np.mean(white_ratios))
  print("there were ", n, "/", len(os.listdir(path)) * 25 ," patches skipped")
  return np_images, np_masks

# %%
train_images, train_mask = get_images(train_path, train_labels_path)
val_images, val_mask = get_images(val_path, val_labels_path)
test_images, test_mask = get_images(test_path, test_labels_path)
# Out:
# /content/tiff/train  Number of files:  137
# skipping:  23279035_15.tiff  White ratio:  0.994232177734375  position:  0 768
# skipping:  23279035_15.tiff  White ratio:  1.0  position:  0 1024
# skipping:  23279035_15.tiff  White ratio:  0.9950103759765625  position:  256 768
# skipping:  23279035_15.tiff  White ratio:  1.0  position:  256 1024
# skipping:  23279035_15.tiff  White ratio:  0.9963531494140625  position:  512 768
# skipping:  23279035_15.tiff  White ratio:  1.0  position:  512 1024
# skipping:  23279035_15.tiff  White ratio:  0.996856689453125  position:  768 768
# skipping:  23279035_15.tiff  White ratio:  1.0  position:  768 1024
# skipping:  23279035_15.tiff  White ratio:  0.9945220947265625  position:  1024 768
# skipping:  23279035_15.tiff  White ratio:  1.0  position:  1024 1024
# skipping:  23129140_15.tiff  White ratio:  1.0  position:  0 0
# skipping:  23129140_15.tiff  White ratio:  0.5476531982421875  position:  0 256
# skipping:  23129140_15.tiff  White ratio:  0.9999847412109375  position:  256 0
# skipping:  23129140_15.tiff  White ratio:  0.5767974853515625  position:  256 256
# skipping:  23129140_15.tiff  White ratio:  1.0  position:  512 0
# skipping:  23129140_15.tiff  White ratio:  0.6065826416015625  position:  512 256
# skipping:  23129140_15.tiff  White ratio:  1.0  position:  768 0
# skipping:  23129140_15.tiff  White ratio:  0.6358489990234375  position:  768 256
# skipping:  23129140_15.tiff  White ratio:  1.0  position:  1024 0
# skipping:  23129140_15.tiff  White ratio:  0.6658172607421875  position:  1024 256
# skipping:  23579125_15.tiff  White ratio:  0.2552642822265625  position:  0 256
# skipping:  23579125_15.tiff  White ratio:  1.0  position:  0 512
# skipping:  23579125_15.tiff  White ratio:  1.0  position:  0 768
# skipping:  23579125_15.tiff  White ratio:  1.0  position:  0 1024
# skipping:  23579125_15.tiff  White ratio:  1.0  position:  256 512
# skipping:  23579125_15.tiff  White ratio:  1.0  position:  256 768
# skipping:  23579125_15.tiff  White ratio:  1.0  position:  256 1024
# skipping:  23579125_15.tiff  White ratio:  1.0  position:  512 512
# skipping:  23579125_15.tiff  White ratio:  1.0  position:  512 768
# skipping:  23579125_15.tiff  White ratio:  1.0  position:  512 1024
# skipping:  23579125_15.tiff  White ratio:  1.0  position:  768 512
# skipping:  23579125_15.tiff  White ratio:  1.0  position:  768 768
# skipping:  23579125_15.tiff  White ratio:  1.0  position:  768 1024
# skipping:  23579125_15.tiff  White ratio:  1.0  position:  1024 512
# skipping:  23579125_15.tiff  White ratio:  1.0  position:  1024 768
# skipping:  23579125_15.tiff  White ratio:  1.0  position:  1024 1024
# skipping:  24029110_15.tiff  White ratio:  1.0  position:  0 512
# skipping:  24029110_15.tiff  White ratio:  1.0  position:  0 768
# skipping:  24029110_15.tiff  White ratio:  1.0  position:  0 1024
# skipping:  24029110_15.tiff  White ratio:  1.0  position:  256 512
# skipping:  24029110_15.tiff  White ratio:  1.0  position:  256 768
# skipping:  24029110_15.tiff  White ratio:  1.0  position:  256 1024
# skipping:  24029110_15.tiff  White ratio:  0.9999237060546875  position:  512 512
# skipping:  24029110_15.tiff  White ratio:  1.0  position:  512 768
# skipping:  24029110_15.tiff  White ratio:  1.0  position:  512 1024
# skipping:  24029110_15.tiff  White ratio:  0.9919586181640625  position:  768 512
# skipping:  24029110_15.tiff  White ratio:  0.999969482421875  position:  768 768
# skipping:  24029110_15.tiff  White ratio:  1.0  position:  768 1024
# skipping:  24029110_15.tiff  White ratio:  0.63140869140625  position:  1024 512
# skipping:  24029110_15.tiff  White ratio:  0.62432861328125  position:  1024 768
# skipping:  24029110_15.tiff  White ratio:  0.5947113037109375  position:  1024 1024
# skipping:  23278885_15.tiff  White ratio:  0.5111083984375  position:  0 1024
# skipping:  23278885_15.tiff  White ratio:  0.4824066162109375  position:  256 1024
# skipping:  23278885_15.tiff  White ratio:  0.4526519775390625  position:  512 1024
# skipping:  23278885_15.tiff  White ratio:  0.423126220703125  position:  768 1024
# skipping:  23278885_15.tiff  White ratio:  0.3932647705078125  position:  1024 1024
# skipping:  23429170_15.tiff  White ratio:  0.780181884765625  position:  0 256
# skipping:  23429170_15.tiff  White ratio:  1.0  position:  0 512
# skipping:  23429170_15.tiff  White ratio:  1.0  position:  0 768
# skipping:  23429170_15.tiff  White ratio:  1.0  position:  0 1024
# skipping:  23429170_15.tiff  White ratio:  0.7502593994140625  position:  256 256
# skipping:  23429170_15.tiff  White ratio:  1.0  position:  256 512
# skipping:  23429170_15.tiff  White ratio:  1.0  position:  256 768
# skipping:  23429170_15.tiff  White ratio:  1.0  position:  256 1024
# skipping:  23429170_15.tiff  White ratio:  0.720367431640625  position:  512 256
# skipping:  23429170_15.tiff  White ratio:  1.0  position:  512 512
# skipping:  23429170_15.tiff  White ratio:  1.0  position:  512 768
# skipping:  23429170_15.tiff  White ratio:  1.0  position:  512 1024
# skipping:  23429170_15.tiff  White ratio:  0.6899566650390625  position:  768 256
# skipping:  23429170_15.tiff  White ratio:  1.0  position:  768 512
# skipping:  23429170_15.tiff  White ratio:  1.0  position:  768 768
# skipping:  23429170_15.tiff  White ratio:  1.0  position:  768 1024
# skipping:  23429170_15.tiff  White ratio:  0.6603851318359375  position:  1024 256
# skipping:  23429170_15.tiff  White ratio:  1.0  position:  1024 512
# skipping:  23429170_15.tiff  White ratio:  1.0  position:  1024 768
# skipping:  23429170_15.tiff  White ratio:  1.0  position:  1024 1024
# skipping:  23579140_15.tiff  White ratio:  0.4295654296875  position:  0 256
# skipping:  23579140_15.tiff  White ratio:  1.0  position:  0 512
# skipping:  23579140_15.tiff  White ratio:  1.0  position:  0 768
# skipping:  23579140_15.tiff  White ratio:  1.0  position:  0 1024
# skipping:  23579140_15.tiff  White ratio:  0.40008544921875  position:  256 256
# skipping:  23579140_15.tiff  White ratio:  1.0  position:  256 512
# skipping:  23579140_15.tiff  White ratio:  1.0  position:  256 768
# skipping:  23579140_15.tiff  White ratio:  1.0  position:  256 1024
# skipping:  23579140_15.tiff  White ratio:  0.369171142578125  position:  512 256
# skipping:  23579140_15.tiff  White ratio:  1.0  position:  512 512
# skipping:  23579140_15.tiff  White ratio:  1.0  position:  512 768
# skipping:  23579140_15.tiff  White ratio:  1.0  position:  512 1024
# skipping:  23579140_15.tiff  White ratio:  0.339630126953125  position:  768 256
# skipping:  23579140_15.tiff  White ratio:  1.0  position:  768 512
# skipping:  23579140_15.tiff  White ratio:  1.0  position:  768 768
# skipping:  23579140_15.tiff  White ratio:  1.0  position:  768 1024
# skipping:  23579140_15.tiff  White ratio:  0.309906005859375  position:  1024 256
# skipping:  23579140_15.tiff  White ratio:  1.0  position:  1024 512
# skipping:  23579140_15.tiff  White ratio:  1.0  position:  1024 768
# skipping:  23579140_15.tiff  White ratio:  1.0  position:  1024 1024
# skipping:  23429050_15.tiff  White ratio:  1.0  position:  0 0
# skipping:  23429050_15.tiff  White ratio:  1.0  position:  0 256
# skipping:  23429050_15.tiff  White ratio:  0.5880279541015625  position:  0 512
# skipping:  23429050_15.tiff  White ratio:  1.0  position:  256 0
# skipping:  23429050_15.tiff  White ratio:  1.0  position:  256 256
# skipping:  23429050_15.tiff  White ratio:  0.6171112060546875  position:  256 512
# skipping:  23429050_15.tiff  White ratio:  1.0  position:  512 0
# skipping:  23429050_15.tiff  White ratio:  1.0  position:  512 256
# skipping:  23429050_15.tiff  White ratio:  0.6462554931640625  position:  512 512
# skipping:  23429050_15.tiff  White ratio:  1.0  position:  768 0
# skipping:  23429050_15.tiff  White ratio:  1.0  position:  768 256
# skipping:  23429050_15.tiff  White ratio:  0.6751251220703125  position:  768 512
# skipping:  23429050_15.tiff  White ratio:  1.0  position:  1024 0
# skipping:  23429050_15.tiff  White ratio:  0.9999542236328125  position:  1024 256
# skipping:  23429050_15.tiff  White ratio:  0.7040252685546875  position:  1024 512
# skipping:  23129170_15.tiff  White ratio:  0.99957275390625  position:  0 0
# skipping:  23129170_15.tiff  White ratio:  0.999603271484375  position:  256 0
# skipping:  23129170_15.tiff  White ratio:  0.9993896484375  position:  512 0
# skipping:  23129170_15.tiff  White ratio:  0.2602386474609375  position:  512 256
# skipping:  23129170_15.tiff  White ratio:  0.9989471435546875  position:  768 0
# skipping:  23129170_15.tiff  White ratio:  0.288238525390625  position:  768 256
# skipping:  23129170_15.tiff  White ratio:  0.99908447265625  position:  1024 0
# skipping:  23129170_15.tiff  White ratio:  0.318878173828125  position:  1024 256
# skipping:  23279050_15.tiff  White ratio:  0.401763916015625  position:  0 512
# skipping:  23279050_15.tiff  White ratio:  0.99884033203125  position:  0 768
# skipping:  23279050_15.tiff  White ratio:  1.0  position:  0 1024
# skipping:  23279050_15.tiff  White ratio:  0.37017822265625  position:  256 512
# skipping:  23279050_15.tiff  White ratio:  0.9980926513671875  position:  256 768
# skipping:  23279050_15.tiff  White ratio:  1.0  position:  256 1024
# skipping:  23279050_15.tiff  White ratio:  0.339599609375  position:  512 512
# skipping:  23279050_15.tiff  White ratio:  0.997314453125  position:  512 768
# skipping:  23279050_15.tiff  White ratio:  1.0  position:  512 1024
# skipping:  23279050_15.tiff  White ratio:  0.3102874755859375  position:  768 512
# skipping:  23279050_15.tiff  White ratio:  0.99749755859375  position:  768 768
# skipping:  23279050_15.tiff  White ratio:  1.0  position:  768 1024
# skipping:  23279050_15.tiff  White ratio:  0.2806549072265625  position:  1024 512
# skipping:  23279050_15.tiff  White ratio:  0.9970703125  position:  1024 768
# skipping:  23279050_15.tiff  White ratio:  1.0  position:  1024 1024
# skipping:  23428900_15.tiff  White ratio:  0.6789398193359375  position:  0 1024
# skipping:  23428900_15.tiff  White ratio:  0.6508331298828125  position:  256 1024
# skipping:  23428900_15.tiff  White ratio:  0.6222686767578125  position:  512 1024
# skipping:  23428900_15.tiff  White ratio:  0.592681884765625  position:  768 1024
# skipping:  23428900_15.tiff  White ratio:  0.563873291015625  position:  1024 1024
# skipping:  24478900_15.tiff  White ratio:  1.0  position:  0 0
# skipping:  24478900_15.tiff  White ratio:  1.0  position:  0 256
# skipping:  24478900_15.tiff  White ratio:  1.0  position:  0 512
# skipping:  24478900_15.tiff  White ratio:  1.0  position:  0 768
# skipping:  24478900_15.tiff  White ratio:  0.3292999267578125  position:  0 1024
# skipping:  24478900_15.tiff  White ratio:  1.0  position:  256 0
# skipping:  24478900_15.tiff  White ratio:  1.0  position:  256 256
# skipping:  24478900_15.tiff  White ratio:  1.0  position:  256 512
# skipping:  24478900_15.tiff  White ratio:  1.0  position:  256 768
# skipping:  24478900_15.tiff  White ratio:  0.3572540283203125  position:  256 1024
# skipping:  24478900_15.tiff  White ratio:  1.0  position:  512 0
# skipping:  24478900_15.tiff  White ratio:  1.0  position:  512 256
# skipping:  24478900_15.tiff  White ratio:  1.0  position:  512 512
# skipping:  24478900_15.tiff  White ratio:  1.0  position:  512 768
# skipping:  24478900_15.tiff  White ratio:  0.384735107421875  position:  512 1024
# skipping:  24478900_15.tiff  White ratio:  1.0  position:  768 0
# skipping:  24478900_15.tiff  White ratio:  1.0  position:  768 256
# skipping:  24478900_15.tiff  White ratio:  1.0  position:  768 512
# skipping:  24478900_15.tiff  White ratio:  1.0  position:  768 768
# skipping:  24478900_15.tiff  White ratio:  0.412261962890625  position:  768 1024
# skipping:  23878930_15.tiff  White ratio:  0.9994354248046875  position:  0 1024
# skipping:  23878930_15.tiff  White ratio:  0.986663818359375  position:  256 1024
# skipping:  23878930_15.tiff  White ratio:  0.9541168212890625  position:  512 1024
# skipping:  23878930_15.tiff  White ratio:  0.9228973388671875  position:  768 1024
# skipping:  23878930_15.tiff  White ratio:  0.892822265625  position:  1024 1024
# skipping:  23429065_15.tiff  White ratio:  1.0  position:  0 0
# skipping:  23429065_15.tiff  White ratio:  0.9998779296875  position:  0 256
# skipping:  23429065_15.tiff  White ratio:  0.4122467041015625  position:  0 512
# skipping:  23429065_15.tiff  White ratio:  1.0  position:  256 0
# skipping:  23429065_15.tiff  White ratio:  0.9997711181640625  position:  256 256
# skipping:  23429065_15.tiff  White ratio:  0.4401702880859375  position:  256 512
# skipping:  23429065_15.tiff  White ratio:  1.0  position:  512 0
# skipping:  23429065_15.tiff  White ratio:  0.9998626708984375  position:  512 256
# skipping:  23429065_15.tiff  White ratio:  0.4718780517578125  position:  512 512
# skipping:  23429065_15.tiff  White ratio:  1.0  position:  768 0
# skipping:  23429065_15.tiff  White ratio:  0.99993896484375  position:  768 256
# skipping:  23429065_15.tiff  White ratio:  0.501739501953125  position:  768 512
# skipping:  23429065_15.tiff  White ratio:  1.0  position:  1024 0
# skipping:  23429065_15.tiff  White ratio:  0.999969482421875  position:  1024 256
# skipping:  23429065_15.tiff  White ratio:  0.5312042236328125  position:  1024 512
# skipping:  23878915_15.tiff  White ratio:  0.839111328125  position:  0 1024
# skipping:  23878915_15.tiff  White ratio:  0.8090057373046875  position:  256 1024
# skipping:  23878915_15.tiff  White ratio:  0.7795562744140625  position:  512 1024
# skipping:  23878915_15.tiff  White ratio:  0.752227783203125  position:  768 1024
# skipping:  23878915_15.tiff  White ratio:  0.774261474609375  position:  1024 1024
# skipping:  24329095_15.tiff  White ratio:  0.5198211669921875  position:  1024 512
# skipping:  24329095_15.tiff  White ratio:  0.6997833251953125  position:  1024 768
# skipping:  24329095_15.tiff  White ratio:  0.729034423828125  position:  1024 1024
# skipping:  23279095_15.tiff  White ratio:  1.0  position:  0 0
# skipping:  23279095_15.tiff  White ratio:  0.999298095703125  position:  0 256
# skipping:  23279095_15.tiff  White ratio:  1.0  position:  256 0
# skipping:  23279095_15.tiff  White ratio:  0.9993896484375  position:  256 256
# skipping:  23279095_15.tiff  White ratio:  1.0  position:  512 0
# skipping:  23279095_15.tiff  White ratio:  0.9990234375  position:  512 256
# skipping:  23279095_15.tiff  White ratio:  1.0  position:  768 0
# skipping:  23279095_15.tiff  White ratio:  0.9990234375  position:  768 256
# skipping:  23279095_15.tiff  White ratio:  1.0  position:  1024 0
# skipping:  23279095_15.tiff  White ratio:  0.999237060546875  position:  1024 256
# skipping:  23579110_15.tiff  White ratio:  1.0  position:  0 512
# skipping:  23579110_15.tiff  White ratio:  1.0  position:  0 768
# skipping:  23579110_15.tiff  White ratio:  1.0  position:  0 1024
# skipping:  23579110_15.tiff  White ratio:  1.0  position:  256 512
# skipping:  23579110_15.tiff  White ratio:  1.0  position:  256 768
# skipping:  23579110_15.tiff  White ratio:  1.0  position:  256 1024
# skipping:  23579110_15.tiff  White ratio:  1.0  position:  512 512
# skipping:  23579110_15.tiff  White ratio:  1.0  position:  512 768
# skipping:  23579110_15.tiff  White ratio:  1.0  position:  512 1024
# skipping:  23579110_15.tiff  White ratio:  0.9972991943359375  position:  768 512
# skipping:  23579110_15.tiff  White ratio:  1.0  position:  768 768
# skipping:  23579110_15.tiff  White ratio:  1.0  position:  768 1024
# skipping:  23579110_15.tiff  White ratio:  0.9721832275390625  position:  1024 512
# skipping:  23579110_15.tiff  White ratio:  0.9999847412109375  position:  1024 768
# skipping:  23579110_15.tiff  White ratio:  1.0  position:  1024 1024
# skipping:  23729110_15.tiff  White ratio:  1.0  position:  0 0
# skipping:  23729110_15.tiff  White ratio:  0.904327392578125  position:  0 256
# skipping:  23729110_15.tiff  White ratio:  1.0  position:  256 0
# skipping:  23729110_15.tiff  White ratio:  0.9336090087890625  position:  256 256
# skipping:  23729110_15.tiff  White ratio:  1.0  position:  512 0
# skipping:  23729110_15.tiff  White ratio:  0.961273193359375  position:  512 256
# skipping:  23729110_15.tiff  White ratio:  1.0  position:  768 0
# skipping:  23729110_15.tiff  White ratio:  0.988433837890625  position:  768 256
# skipping:  23729110_15.tiff  White ratio:  0.9998626708984375  position:  1024 0
# skipping:  23729110_15.tiff  White ratio:  0.9990386962890625  position:  1024 256
# skipping:  23279080_15.tiff  White ratio:  1.0  position:  0 0
# skipping:  23279080_15.tiff  White ratio:  0.999420166015625  position:  0 256
# skipping:  23279080_15.tiff  White ratio:  1.0  position:  256 0
# skipping:  23279080_15.tiff  White ratio:  0.99945068359375  position:  256 256
# skipping:  23279080_15.tiff  White ratio:  0.264923095703125  position:  256 512
# skipping:  23279080_15.tiff  White ratio:  1.0  position:  512 0
# skipping:  23279080_15.tiff  White ratio:  0.999298095703125  position:  512 256
# skipping:  23279080_15.tiff  White ratio:  0.2929534912109375  position:  512 512
# skipping:  23279080_15.tiff  White ratio:  1.0  position:  768 0
# skipping:  23279080_15.tiff  White ratio:  0.99957275390625  position:  768 256
# skipping:  23279080_15.tiff  White ratio:  0.3223419189453125  position:  768 512
# skipping:  23279080_15.tiff  White ratio:  1.0  position:  1024 0
# skipping:  23279080_15.tiff  White ratio:  0.999755859375  position:  1024 256
# skipping:  23279080_15.tiff  White ratio:  0.3526611328125  position:  1024 512
# skipping:  23128870_15.tiff  White ratio:  0.34063720703125  position:  0 1024
# skipping:  23128870_15.tiff  White ratio:  0.31195068359375  position:  256 1024
# skipping:  23128870_15.tiff  White ratio:  0.28253173828125  position:  512 1024
# skipping:  23128870_15.tiff  White ratio:  0.25347900390625  position:  768 1024
# skipping:  23129065_15.tiff  White ratio:  0.5791778564453125  position:  0 512
# skipping:  23129065_15.tiff  White ratio:  0.999755859375  position:  0 768
# skipping:  23129065_15.tiff  White ratio:  1.0  position:  0 1024
# skipping:  23129065_15.tiff  White ratio:  0.5485687255859375  position:  256 512
# skipping:  23129065_15.tiff  White ratio:  0.9995269775390625  position:  256 768
# skipping:  23129065_15.tiff  White ratio:  1.0  position:  256 1024
# skipping:  23129065_15.tiff  White ratio:  0.51837158203125  position:  512 512
# skipping:  23129065_15.tiff  White ratio:  0.99932861328125  position:  512 768
# skipping:  23129065_15.tiff  White ratio:  1.0  position:  512 1024
# skipping:  23129065_15.tiff  White ratio:  0.48822021484375  position:  768 512
# skipping:  23129065_15.tiff  White ratio:  0.99908447265625  position:  768 768
# skipping:  23129065_15.tiff  White ratio:  1.0  position:  768 1024
# skipping:  23129065_15.tiff  White ratio:  0.458099365234375  position:  1024 512
# skipping:  23129065_15.tiff  White ratio:  0.9990692138671875  position:  1024 768
# skipping:  23129065_15.tiff  White ratio:  1.0  position:  1024 1024
# skipping:  23129125_15.tiff  White ratio:  1.0  position:  0 0
# skipping:  23129125_15.tiff  White ratio:  0.7207489013671875  position:  0 256
# skipping:  23129125_15.tiff  White ratio:  1.0  position:  256 0
# skipping:  23129125_15.tiff  White ratio:  0.7498626708984375  position:  256 256
# skipping:  23129125_15.tiff  White ratio:  1.0  position:  512 0
# skipping:  23129125_15.tiff  White ratio:  0.7797393798828125  position:  512 256
# skipping:  23129125_15.tiff  White ratio:  1.0  position:  768 0
# skipping:  23129125_15.tiff  White ratio:  0.8091583251953125  position:  768 256
# skipping:  23129125_15.tiff  White ratio:  1.0  position:  1024 0
# skipping:  23129125_15.tiff  White ratio:  0.838623046875  position:  1024 256
# skipping:  24328870_15.tiff  White ratio:  1.0  position:  0 0
# skipping:  24328870_15.tiff  White ratio:  1.0  position:  0 256
# skipping:  24328870_15.tiff  White ratio:  1.0  position:  0 512
# skipping:  24328870_15.tiff  White ratio:  1.0  position:  0 768
# skipping:  24328870_15.tiff  White ratio:  0.66253662109375  position:  0 1024
# skipping:  24328870_15.tiff  White ratio:  1.0  position:  256 0
# skipping:  24328870_15.tiff  White ratio:  1.0  position:  256 256
# skipping:  24328870_15.tiff  White ratio:  1.0  position:  256 512
# skipping:  24328870_15.tiff  White ratio:  1.0  position:  256 768
# skipping:  24328870_15.tiff  White ratio:  0.6995086669921875  position:  256 1024
# skipping:  24328870_15.tiff  White ratio:  1.0  position:  512 0
# skipping:  24328870_15.tiff  White ratio:  1.0  position:  512 256
# skipping:  24328870_15.tiff  White ratio:  1.0  position:  512 512
# skipping:  24328870_15.tiff  White ratio:  1.0  position:  512 768
# skipping:  24328870_15.tiff  White ratio:  0.728057861328125  position:  512 1024
# skipping:  24328870_15.tiff  White ratio:  1.0  position:  768 0
# skipping:  24328870_15.tiff  White ratio:  1.0  position:  768 256
# skipping:  24328870_15.tiff  White ratio:  1.0  position:  768 512
# skipping:  24328870_15.tiff  White ratio:  1.0  position:  768 768
# skipping:  24328870_15.tiff  White ratio:  0.7555694580078125  position:  768 1024
# skipping:  24328870_15.tiff  White ratio:  0.4131927490234375  position:  1024 0
# skipping:  24328870_15.tiff  White ratio:  0.3838348388671875  position:  1024 256
# skipping:  24328870_15.tiff  White ratio:  0.3568878173828125  position:  1024 512
# skipping:  24328870_15.tiff  White ratio:  0.32904052734375  position:  1024 768
# skipping:  23129155_15.tiff  White ratio:  0.999847412109375  position:  0 0
# skipping:  23129155_15.tiff  White ratio:  0.3745574951171875  position:  0 256
# skipping:  23129155_15.tiff  White ratio:  0.9999542236328125  position:  256 0
# skipping:  23129155_15.tiff  White ratio:  0.40374755859375  position:  256 256
# skipping:  23129155_15.tiff  White ratio:  0.9999542236328125  position:  512 0
# skipping:  23129155_15.tiff  White ratio:  0.4332427978515625  position:  512 256
# skipping:  23129155_15.tiff  White ratio:  0.999969482421875  position:  768 0
# skipping:  23129155_15.tiff  White ratio:  0.4629669189453125  position:  768 256
# skipping:  23129155_15.tiff  White ratio:  0.99993896484375  position:  1024 0
# skipping:  23129155_15.tiff  White ratio:  0.4927520751953125  position:  1024 256
# skipping:  23429035_15.tiff  White ratio:  1.0  position:  0 0
# skipping:  23429035_15.tiff  White ratio:  0.999969482421875  position:  0 256
# skipping:  23429035_15.tiff  White ratio:  0.7578887939453125  position:  0 512
# skipping:  23429035_15.tiff  White ratio:  1.0  position:  256 0
# skipping:  23429035_15.tiff  White ratio:  0.999969482421875  position:  256 256
# skipping:  23429035_15.tiff  White ratio:  0.78765869140625  position:  256 512
# skipping:  23429035_15.tiff  White ratio:  1.0  position:  512 0
# skipping:  23429035_15.tiff  White ratio:  1.0  position:  512 256
# skipping:  23429035_15.tiff  White ratio:  0.818115234375  position:  512 512
# skipping:  23429035_15.tiff  White ratio:  1.0  position:  768 0
# skipping:  23429035_15.tiff  White ratio:  1.0  position:  768 256
# skipping:  23429035_15.tiff  White ratio:  0.8480987548828125  position:  768 512
# skipping:  23429035_15.tiff  White ratio:  1.0  position:  1024 0
# skipping:  23429035_15.tiff  White ratio:  1.0  position:  1024 256
# skipping:  23429035_15.tiff  White ratio:  0.8771209716796875  position:  1024 512
# skipping:  23878945_15.tiff  White ratio:  0.9979248046875  position:  0 1024
# skipping:  23878945_15.tiff  White ratio:  0.9977569580078125  position:  256 1024
# skipping:  23878945_15.tiff  White ratio:  0.995849609375  position:  512 1024
# skipping:  23878945_15.tiff  White ratio:  0.99505615234375  position:  768 1024
# skipping:  23878945_15.tiff  White ratio:  0.9951324462890625  position:  1024 1024
# images shape:  (3106, 256, 256, 3)
# masks shape:  (3106, 256, 256)
# 0.08186277514826643
# there were  320 / 3425  patches skipped
# /content/tiff/val  Number of files:  4
# images shape:  (100, 256, 256, 3)
# masks shape:  (100, 256, 256)
# 7.62939453125e-07
# there were  1 / 100  patches skipped
# /content/tiff/test  Number of files:  10
# images shape:  (250, 256, 256, 3)
# masks shape:  (250, 256, 256)
# 1.3427734375e-06
# there were  1 / 250  patches skipped

# %%
print("images shape: ",train_images.shape, val_images.shape, test_images.shape)
print("masks shape:  ", train_mask.shape, val_mask.shape, test_mask.shape)
# Out:
# images shape:  (3106, 256, 256, 3) (100, 256, 256, 3) (250, 256, 256, 3)
# masks shape:   (3106, 256, 256) (100, 256, 256) (250, 256, 256)

# %%
# plot images from train_images
fig, axes = plt.subplots(5, 5, figsize=(15, 15))
for i in range(25):
  x = random.choice(train_images)

  axes[i//5, i%5].imshow(x)
  axes[i//5, i%5].axis('off')
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Below cell saves the computed images in the numpy array to a file.

# %%
import imageio

def save_images(images, masks, output_folder):
  # Directory to save TIFF images
  # output_folder = "train"

  # Create the output folder if it doesn't exist
  os.makedirs(output_folder, exist_ok=True)

  # Save each image as a TIFF file
  for i, image in enumerate(images):
    image_path = os.path.join(output_folder, f"image_{i+1}.tiff")
    imageio.imwrite(image_path, image)

  for i, mask in enumerate(masks):
      mask_path = os.path.join(output_folder, f"mask_{i+1}.tif")
      imageio.imwrite(mask_path, mask)

  print("TIFF images saved successfully.")

# %%
# save to seperate folders

save_images(train_images, train_mask, "train")
save_images(val_images, val_mask, "val")
save_images(test_images, test_mask, "test")
# Out:
# TIFF images saved successfully.
# TIFF images saved successfully.
# TIFF images saved successfully.

# %%
# zips the train val and test folders
# !zip -r -q cropped_data.zip train val test

# %%
len(os.listdir("train")), len(os.listdir("val")), len(os.listdir("test"))
# Out:
# (6212, 200, 500)

# %%
# save to google drive
# !cp cropped_data.zip /content/drive/MyDrive/buildingSegmentation/cropped_data_v4.zip
